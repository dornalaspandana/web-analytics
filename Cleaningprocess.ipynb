# %%
import pandas as pd  # Importing the pandas library for data manipulation

# Step 1: Loading the dataset
df = pd.read_csv("Assignment1Data_Sample.csv")  # Reading the dataset from a CSV file into a DataFrame

df
# Out:
#            Object Number  Object ID                Department  \
# 0                  62.16       1674  American Decorative Arts
# 1                13.7.17       2430  American Decorative Arts
# 2               33.85.11       6406  American Decorative Arts
# 3             69.194.109       7616  American Decorative Arts
# 4            2006.235.20      15012  American Decorative Arts
# ..                   ...        ...                       ...
# 199  63.350.329.701-1.16     779306       Drawings and Prints
# 200    63.350.244.87.182     785013       Drawings and Prints
# 201         1980.1119(1)     813925       Drawings and Prints
# 202        1986.1180.249     820618       Drawings and Prints
# 203            67.744.50     824428       Drawings and Prints
#
#              Object Name                                              Title  \
# 0             Side Chair                                         Side Chair
# 1                Pitcher                                    Covered Pitcher
# 2                  Plate                                              Plate
# 3              Soup bowl                                          Soup Bowl
# 4    Painting, miniature                                 Portrait of a Lady
# ..                   ...                                                ...
# 199           Trade card  Packard-Tourist, from the "Antique Autos" seri...
# 200      Print; ephemera  Norwegian Air Force In Canada Patrol Bomber (N...
# 201                Print                                         Stonehenge
# 202                Print  Psyche, holding the flask of beauty being tran...
# 203                Print                               Landscape and Cattle
#
#       Culture Period Dynasty Reign                            Portfolio  ...  \
# 0    American    NaN     NaN   NaN                                  NaN  ...
# 1    American    NaN     NaN   NaN                                  NaN  ...
# 2       Dutch    NaN     NaN   NaN                                  NaN  ...
# 3    American    NaN     NaN   NaN                                  NaN  ...
# 4    American    NaN     NaN   NaN                                  NaN  ...
# ..        ...    ...     ...   ...                                  ...  ...
# 199       NaN    NaN     NaN   NaN                                  NaN  ...
# 200       NaN    NaN     NaN   NaN                                  NaN  ...
# 201       NaN    NaN     NaN   NaN                 Ruins and Landscapes  ...
# 202       NaN    NaN     NaN   NaN                                  NaN  ...
# 203       NaN    NaN     NaN   NaN  New York and Long Island Landscapes  ...
#
#     Locale Locus Excavation River   Classification Rights and Reproduction  \
# 0      NaN   NaN        NaN   NaN        Furniture                     NaN
# 1      NaN   NaN        NaN   NaN         Ceramics                     NaN
# 2      NaN   NaN        NaN   NaN         Ceramics                     NaN
# 3      NaN   NaN        NaN   NaN         Ceramics                     NaN
# 4      NaN   NaN        NaN   NaN        Paintings                     NaN
# ..     ...   ...        ...   ...              ...                     ...
# 199    NaN   NaN        NaN   NaN  Prints|Ephemera                     NaN
# 200    NaN   NaN        NaN   NaN  Prints|Ephemera                     NaN
# 201    NaN   NaN        NaN   NaN           Prints     © Philip Pearlstein
# 202    NaN   NaN        NaN   NaN           Prints                     NaN
# 203    NaN   NaN        NaN   NaN           Prints                     NaN
#
#                                          Link Resource   Metadata Date  \
# 0    http://www.metmuseum.org/art/collection/search...  5/13/2019 8:00
# 1    http://www.metmuseum.org/art/collection/search...  5/13/2019 8:00
# 2    http://www.metmuseum.org/art/collection/search...  5/13/2019 8:00
# 3    http://www.metmuseum.org/art/collection/search...  5/13/2019 8:00
# 4    http://www.metmuseum.org/art/collection/search...  5/13/2019 8:00
# ..                                                 ...             ...
# 199  http://www.metmuseum.org/art/collection/search...  5/13/2019 8:00
# 200  http://www.metmuseum.org/art/collection/search...  5/13/2019 8:00
# 201  http://www.metmuseum.org/art/collection/search...  5/13/2019 8:00
# 202  http://www.metmuseum.org/art/collection/search...  5/13/2019 8:00
# 203  http://www.metmuseum.org/art/collection/search...  5/13/2019 8:00
#
#                                    Repository                      Tags
# 0    Metropolitan Museum of Art, New York, NY                    Chairs
# 1    Metropolitan Museum of Art, New York, NY                  Pitchers
# 2    Metropolitan Museum of Art, New York, NY                       NaN
# 3    Metropolitan Museum of Art, New York, NY                     Bowls
# 4    Metropolitan Museum of Art, New York, NY  Pendants|Portraits|Women
# ..                                        ...                       ...
# 199  Metropolitan Museum of Art, New York, NY                       NaN
# 200  Metropolitan Museum of Art, New York, NY                       NaN
# 201  Metropolitan Museum of Art, New York, NY                       NaN
# 202  Metropolitan Museum of Art, New York, NY                  Adam|Eve
# 203  Metropolitan Museum of Art, New York, NY                       NaN
#
# [204 rows x 41 columns]

# %%
# Step 2: Keeping only the required columns
# Defining the list of required columns we need for our analysis
required_columns = [
    "Object ID", 
    "Department", 
    "Object Name", 
    "Title", 
    "Culture", 
    "Artist Nationality", 
    "Object Begin Date", 
    "Object End Date", 
    "Medium", 
    "Credit Line", 
    "Country"
]
# Filtering the DataFrame to keep only the required columns and creating a copy
df = df[required_columns].copy()
df
# Out:
#      Object ID                Department          Object Name  \
# 0         1674  American Decorative Arts           Side Chair
# 1         2430  American Decorative Arts              Pitcher
# 2         6406  American Decorative Arts                Plate
# 3         7616  American Decorative Arts            Soup bowl
# 4        15012  American Decorative Arts  Painting, miniature
# ..         ...                       ...                  ...
# 199     779306       Drawings and Prints           Trade card
# 200     785013       Drawings and Prints      Print; ephemera
# 201     813925       Drawings and Prints                Print
# 202     820618       Drawings and Prints                Print
# 203     824428       Drawings and Prints                Print
#
#                                                  Title   Culture  \
# 0                                           Side Chair  American
# 1                                      Covered Pitcher  American
# 2                                                Plate     Dutch
# 3                                            Soup Bowl  American
# 4                                   Portrait of a Lady  American
# ..                                                 ...       ...
# 199  Packard-Tourist, from the "Antique Autos" seri...       NaN
# 200  Norwegian Air Force In Canada Patrol Bomber (N...       NaN
# 201                                         Stonehenge       NaN
# 202  Psyche, holding the flask of beauty being tran...       NaN
# 203                               Landscape and Cattle       NaN
#
#     Artist Nationality  Object Begin Date  Object End Date  \
# 0                  NaN               1794           1799.0
# 1                  NaN               1700           1900.0
# 2                  NaN               1740           1760.0
# 3                  NaN               1885           1885.0
# 4                  NaN               1840           1840.0
# ..                 ...                ...              ...
# 199                NaN               1953           1953.0
# 200                NaN               1942           1942.0
# 201                NaN               1979           1979.0
# 202                NaN               1525           1535.0
# 203                NaN               1875           1885.0
#
#                                       Medium  \
# 0    Mahogany, ebony, ash, birch, white pine
# 1                                Earthenware
# 2                                Earthenware
# 3                                  Porcelain
# 4                        Watercolor on ivory
# ..                                       ...
# 199              Commercial color lithograph
# 200              Commercial color lithograph
# 201        Sugar-lift aquatint with roulette
# 202                                Engraving
# 203                                  Etching
#
#                                            Credit Line        Country
# 0              Friends of the American Wing Fund, 1962  United States
# 1                                    Rogers Fund, 1913  United States
# 2                                    Rogers Fund, 1933    Netherlands
# 3            Gift of Mr. and Mrs. Franklin Chace, 1969  United States
# 4                                  Fletcher Fund, 2006            NaN
# ..                                                 ...            ...
# 199  The Jefferson R. Burdick Collection, Gift of J...            NaN
# 200  The Jefferson R. Burdick Collection, Gift of J...            NaN
# 201                        Gift of Jerry S. Flum, 1980            NaN
# 202                        Bequest of Grace Pugh, 1985            NaN
# 203                         Gift of Henry Levien, 1967            NaN
#
# [204 rows x 11 columns]

# %%
# Step 3: Identifying missing values in all required columns
# Calculating the number of missing values in each column
missing_values = df.isnull().sum()  
print(f"Missing values in each column:\n{missing_values}\n")  # Printing the missing values count
# Out:
# Missing values in each column:
# Object ID               0
# Department              1
# Object Name             1
# Title                  10
# Culture               120
# Artist Nationality    117
# Object Begin Date       0
# Object End Date         2
# Medium                  2
# Credit Line             0
# Country               172
# dtype: int64

# %%
# Step 4: Filling the missing values in less critical fields
# Filling the missing values in specified columns with "Unknown"
df["Culture"] = df["Culture"].fillna("Unknown")  # Fill the missing Culture with "Unknown"
df["Artist Nationality"] = df["Artist Nationality"].fillna("Unknown")  # Filling the missing Artist Nationality
df["Credit Line"] = df["Credit Line"].fillna("Unknown")  # Filling the missing Credit Line
df["Country"] = df["Country"].fillna("Unknown")  # Filling the missing Country

df
# Out:
#      Object ID                Department          Object Name  \
# 0         1674  American Decorative Arts           Side Chair
# 1         2430  American Decorative Arts              Pitcher
# 2         6406  American Decorative Arts                Plate
# 3         7616  American Decorative Arts            Soup bowl
# 4        15012  American Decorative Arts  Painting, miniature
# ..         ...                       ...                  ...
# 199     779306       Drawings and Prints           Trade card
# 200     785013       Drawings and Prints      Print; ephemera
# 201     813925       Drawings and Prints                Print
# 202     820618       Drawings and Prints                Print
# 203     824428       Drawings and Prints                Print
#
#                                                  Title   Culture  \
# 0                                           Side Chair  American
# 1                                      Covered Pitcher  American
# 2                                                Plate     Dutch
# 3                                            Soup Bowl  American
# 4                                   Portrait of a Lady  American
# ..                                                 ...       ...
# 199  Packard-Tourist, from the "Antique Autos" seri...   Unknown
# 200  Norwegian Air Force In Canada Patrol Bomber (N...   Unknown
# 201                                         Stonehenge   Unknown
# 202  Psyche, holding the flask of beauty being tran...   Unknown
# 203                               Landscape and Cattle   Unknown
#
#     Artist Nationality  Object Begin Date  Object End Date  \
# 0              Unknown               1794           1799.0
# 1              Unknown               1700           1900.0
# 2              Unknown               1740           1760.0
# 3              Unknown               1885           1885.0
# 4              Unknown               1840           1840.0
# ..                 ...                ...              ...
# 199            Unknown               1953           1953.0
# 200            Unknown               1942           1942.0
# 201            Unknown               1979           1979.0
# 202            Unknown               1525           1535.0
# 203            Unknown               1875           1885.0
#
#                                       Medium  \
# 0    Mahogany, ebony, ash, birch, white pine
# 1                                Earthenware
# 2                                Earthenware
# 3                                  Porcelain
# 4                        Watercolor on ivory
# ..                                       ...
# 199              Commercial color lithograph
# 200              Commercial color lithograph
# 201        Sugar-lift aquatint with roulette
# 202                                Engraving
# 203                                  Etching
#
#                                            Credit Line        Country
# 0              Friends of the American Wing Fund, 1962  United States
# 1                                    Rogers Fund, 1913  United States
# 2                                    Rogers Fund, 1933    Netherlands
# 3            Gift of Mr. and Mrs. Franklin Chace, 1969  United States
# 4                                  Fletcher Fund, 2006        Unknown
# ..                                                 ...            ...
# 199  The Jefferson R. Burdick Collection, Gift of J...        Unknown
# 200  The Jefferson R. Burdick Collection, Gift of J...        Unknown
# 201                        Gift of Jerry S. Flum, 1980        Unknown
# 202                        Bequest of Grace Pugh, 1985        Unknown
# 203                         Gift of Henry Levien, 1967        Unknown
#
# [204 rows x 11 columns]

# %%
# Step 5: Ensuring consistency in categorical fields
# Standardising the entries in categorical fields
df["Culture"] = df["Culture"].str.title()  # Capitalizing each word in the Culture column
df["Artist Nationality"] = df["Artist Nationality"].str.title()  # Capitalizing each word in Artist Nationality
df["Country"] = df["Country"].str.strip().replace({"U.S.A.": "United States"}).str.title()  # Cleaning Country names

df
# Out:
#      Object ID                Department          Object Name  \
# 0         1674  American Decorative Arts           Side Chair
# 1         2430  American Decorative Arts              Pitcher
# 2         6406  American Decorative Arts                Plate
# 3         7616  American Decorative Arts            Soup bowl
# 4        15012  American Decorative Arts  Painting, miniature
# ..         ...                       ...                  ...
# 199     779306       Drawings and Prints           Trade card
# 200     785013       Drawings and Prints      Print; ephemera
# 201     813925       Drawings and Prints                Print
# 202     820618       Drawings and Prints                Print
# 203     824428       Drawings and Prints                Print
#
#                                                  Title   Culture  \
# 0                                           Side Chair  American
# 1                                      Covered Pitcher  American
# 2                                                Plate     Dutch
# 3                                            Soup Bowl  American
# 4                                   Portrait of a Lady  American
# ..                                                 ...       ...
# 199  Packard-Tourist, from the "Antique Autos" seri...   Unknown
# 200  Norwegian Air Force In Canada Patrol Bomber (N...   Unknown
# 201                                         Stonehenge   Unknown
# 202  Psyche, holding the flask of beauty being tran...   Unknown
# 203                               Landscape and Cattle   Unknown
#
#     Artist Nationality  Object Begin Date  Object End Date  \
# 0              Unknown               1794           1799.0
# 1              Unknown               1700           1900.0
# 2              Unknown               1740           1760.0
# 3              Unknown               1885           1885.0
# 4              Unknown               1840           1840.0
# ..                 ...                ...              ...
# 199            Unknown               1953           1953.0
# 200            Unknown               1942           1942.0
# 201            Unknown               1979           1979.0
# 202            Unknown               1525           1535.0
# 203            Unknown               1875           1885.0
#
#                                       Medium  \
# 0    Mahogany, ebony, ash, birch, white pine
# 1                                Earthenware
# 2                                Earthenware
# 3                                  Porcelain
# 4                        Watercolor on ivory
# ..                                       ...
# 199              Commercial color lithograph
# 200              Commercial color lithograph
# 201        Sugar-lift aquatint with roulette
# 202                                Engraving
# 203                                  Etching
#
#                                            Credit Line        Country
# 0              Friends of the American Wing Fund, 1962  United States
# 1                                    Rogers Fund, 1913  United States
# 2                                    Rogers Fund, 1933    Netherlands
# 3            Gift of Mr. and Mrs. Franklin Chace, 1969  United States
# 4                                  Fletcher Fund, 2006        Unknown
# ..                                                 ...            ...
# 199  The Jefferson R. Burdick Collection, Gift of J...        Unknown
# 200  The Jefferson R. Burdick Collection, Gift of J...        Unknown
# 201                        Gift of Jerry S. Flum, 1980        Unknown
# 202                        Bequest of Grace Pugh, 1985        Unknown
# 203                         Gift of Henry Levien, 1967        Unknown
#
# [204 rows x 11 columns]

# %%
# Step 6: Logical date checking (removing rows where Object End Date is before Object Begin Date)
# Filtering the DataFrame to keep only rows where the end date is not before the begin date
df = df[df["Object End Date"] >= df["Object Begin Date"]]

df
# Out:
#      Object ID                Department          Object Name  \
# 0         1674  American Decorative Arts           Side Chair
# 1         2430  American Decorative Arts              Pitcher
# 2         6406  American Decorative Arts                Plate
# 3         7616  American Decorative Arts            Soup bowl
# 4        15012  American Decorative Arts  Painting, miniature
# ..         ...                       ...                  ...
# 199     779306       Drawings and Prints           Trade card
# 200     785013       Drawings and Prints      Print; ephemera
# 201     813925       Drawings and Prints                Print
# 202     820618       Drawings and Prints                Print
# 203     824428       Drawings and Prints                Print
#
#                                                  Title   Culture  \
# 0                                           Side Chair  American
# 1                                      Covered Pitcher  American
# 2                                                Plate     Dutch
# 3                                            Soup Bowl  American
# 4                                   Portrait of a Lady  American
# ..                                                 ...       ...
# 199  Packard-Tourist, from the "Antique Autos" seri...   Unknown
# 200  Norwegian Air Force In Canada Patrol Bomber (N...   Unknown
# 201                                         Stonehenge   Unknown
# 202  Psyche, holding the flask of beauty being tran...   Unknown
# 203                               Landscape and Cattle   Unknown
#
#     Artist Nationality  Object Begin Date  Object End Date  \
# 0              Unknown               1794           1799.0
# 1              Unknown               1700           1900.0
# 2              Unknown               1740           1760.0
# 3              Unknown               1885           1885.0
# 4              Unknown               1840           1840.0
# ..                 ...                ...              ...
# 199            Unknown               1953           1953.0
# 200            Unknown               1942           1942.0
# 201            Unknown               1979           1979.0
# 202            Unknown               1525           1535.0
# 203            Unknown               1875           1885.0
#
#                                       Medium  \
# 0    Mahogany, ebony, ash, birch, white pine
# 1                                Earthenware
# 2                                Earthenware
# 3                                  Porcelain
# 4                        Watercolor on ivory
# ..                                       ...
# 199              Commercial color lithograph
# 200              Commercial color lithograph
# 201        Sugar-lift aquatint with roulette
# 202                                Engraving
# 203                                  Etching
#
#                                            Credit Line        Country
# 0              Friends of the American Wing Fund, 1962  United States
# 1                                    Rogers Fund, 1913  United States
# 2                                    Rogers Fund, 1933    Netherlands
# 3            Gift of Mr. and Mrs. Franklin Chace, 1969  United States
# 4                                  Fletcher Fund, 2006        Unknown
# ..                                                 ...            ...
# 199  The Jefferson R. Burdick Collection, Gift of J...        Unknown
# 200  The Jefferson R. Burdick Collection, Gift of J...        Unknown
# 201                        Gift of Jerry S. Flum, 1980        Unknown
# 202                        Bequest of Grace Pugh, 1985        Unknown
# 203                         Gift of Henry Levien, 1967        Unknown
#
# [201 rows x 11 columns]

# %%
# Step 7: Saving the cleaned dataset
# Saving the cleaned DataFrame to a new CSV file
df.to_csv("cleaned_Assignment1Data_Sample.csv", index=False)
